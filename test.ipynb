# %%
import streamlit as st

st.title("Echo Bot")

# Initialize chat history
if "messages" not in st.session_state:
    st.session_state.messages = []


# Display chat messages from history on app rerun
for message in st.session_state.messages:
    print(type(message))
    with st.chat_message(message["role"]):
        st.markdown(message["content"])
# Out:
# 2026-05-27 01:39:39.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-27 01:39:39.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-27 01:39:39.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-27 01:39:39.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-27 01:39:39.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
test["messages"] = []
test["hoge"] = ["a"]
for t in test:
    print(t)
# Out:
# messages
# hoge

# %%
ary = ["hoge", "foo", "bar"]
print(*ary)
ary2 = []
ary2.append(ary)
ary2
# Out:
# hoge foo bar
# [['hoge', 'foo', 'bar']]

# %%
ary3 = [*ary]
ary3
# Out:
# ['hoge', 'foo', 'bar']

# %%
from urllib.parse import urlparse

result = urlparse("https:/www.yahoo.co.jp")
print(result.scheme)
print(result.netloc)
print(all([result.scheme, result.netloc]))
# Out:
# https
#
# False

# %%
import requests
from readability import Document
from bs4 import BeautifulSoup
url = "https://hogelog.com/about"
response = requests.get(url)
response.encoding = response.apparent_encoding

doc = Document(response.text)


soup = BeautifulSoup(doc.summary(), "html.parser")
soup.get_text(strip=True)
# Out:
# 'プロフィール2020.06.032019.05.30当サイトへアクセスいただき、ありがとうございます。誰？簡単なプロフィールです。Memo名前：似非プログラマ年齢：30台後半家族：妻、子供2人(娘、息子)学歴：理系学部卒職業：会社員(企画系の仕事です)趣味：子育て、プログラミング、スポーツ観戦好きな言語：Ruby、Pythonなんで似非プログラマ？平日は中堅電気メーカーの企画部署で働いています。企画業務の傍ら、ルーチンワークをPythonとRubyで自動化することに全力を注いでいます。後輩にはExcelよりPythonと吹き込み洗脳しています。部署の簡易的なWebシステムをRuby on Railsで作ったりもしています。土日はRubyやPythonでコーディングしたり、バイトでプログラミングを教えたりしています。プログラミングが好きで、プログラムを書いて部署からは(一応)評価されていますが、商用プログラムを書いている”本職”ではないです。だから”似非”としました。本職となれるように日々勉強中です。どんなブログ？自分の備忘録も兼ねたブログです。雑記ブログです。ブログを始めた理由は2つあります。とりあえず何か新しいことをしたい。とても尊敬する昔の上司に言われた言葉「知識を自分のものしたいならアウトプットしろ」、「お金は人に配ると減るが、知識は他人に配る(教える)と増える」を最近思い出し、アウトプットしようと思い立ちました。色々役立つことを書いていこうと思いますので、よろしくお願いします。'
